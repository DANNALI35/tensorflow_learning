# %% [markdown]
# 以线性回归均方误差函数为例，假设偏置项b=0，下图展现了均方误差函数相对参数W的图形，为convex函数。convex函数可以采用对参数求导的方式获取极值点，也就是均方误差最小的点。

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
tf.set_random_seed(777)  # for reproducibility

X = [1, 2, 3]
Y = [1, 2, 3]

W = tf.placeholder(tf.float32)

# Our hypothesis for linear model X * W
hypothesis = X * W

# cost/loss function
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# Launch the graph in a session.
sess = tf.Session()

# Variables for plotting cost function
W_history = []
cost_history = []

for i in range(-30, 50):
    curr_W = i * 0.1
    curr_cost = sess.run(cost, feed_dict={W: curr_W})
    W_history.append(curr_W)
    cost_history.append(curr_cost)

# Show the cost function
plt.plot(W_history, cost_history)
plt.show()
# Out:
# C:\Users\lidan\Anaconda3\lib\site-packages\requests\__init__.py:80: RequestsDependencyWarning: urllib3 (1.22) or chardet (2.3.0) doesn't match a supported version!
#   RequestsDependencyWarning)

# %% [markdown]
# 还是以线性回归均方误差函数为例，如果偏置项b!=0,那么权重W和b与cost的关系图像将会是碗状，cost函数同样是convex函数，可用梯度下降法求解极值

# %% [markdown]
# <img src="data:image/png;base64,..." img width="500" />
